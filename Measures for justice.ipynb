# %% [markdown]
# # Measures for Justice data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
sb.set()
# %matplotlib inline

# %% [markdown]
# ### Exploratory analysis

# %%
data = pd.read_csv('data-pa.csv')
# Out:
# /home/caro/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    measure_id  filter_id  start_year  end_year location_id  numerator  \
# 0           7          1        2009      2013          PA    98382.0
# 1           7          1        2009      2013       PA001      741.0
# 2           7          1        2009      2013       PA003     6643.0
# 3           7          1        2009      2013       PA005      356.0
# 4           7          1        2009      2013       PA007     1452.0
#
#    denominator    value  missing  missing_percentage                  status  \
# 0     134310.0  73.2499   8035.0              5.6447     HIGH_MISSING_UNFILT
# 1       1051.0  70.5043     19.0              1.7757                      OK
# 2      10520.0  63.1464    645.0              5.7770     HIGH_MISSING_UNFILT
# 3        475.0  74.9474    150.0             24.0000  EXCEEDS_MISSING_UNFILT
# 4       1784.0  81.3901     63.0              3.4109                      OK
#
#    count  sum  sum_squares  minimum  maximum  standard_deviation  average
# ...

# %%
data.shape
# Out:
# (200736, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200736 entries, 0 to 200735
# Data columns (total 18 columns):
# measure_id            200736 non-null int64
# filter_id             200736 non-null int64
# start_year            200736 non-null int64
# end_year              200736 non-null int64
# location_id           200736 non-null object
# numerator             105196 non-null float64
# denominator           105196 non-null float64
# value                 98762 non-null object
# missing               142868 non-null float64
# missing_percentage    96284 non-null float64
# status                200736 non-null object
# count                 37672 non-null float64
# sum                   37672 non-null float64
# sum_squares           37672 non-null float64
# minimum               37672 non-null float64
# maximum               37672 non-null float64
# standard_deviation    25940 non-null float64
# average               25940 non-null float64
# ...

# %%
measures = pd.read_csv('measures.csv')

# %%
measures.head()
# Out:
#    id                                               name      format  \
# 0   1  Non-Custodial Promise to Appear Instead of Cus...  percentage
# 1   2                               Cases Not Prosecuted  percentage
# 2   6                         Time to Initial Appearance      median
# 3   7  Nonviolent Misdemeanor Cases with Nonmonetary ...  percentage
# 4   8                   Failure to Pay Low Monetary Bail  percentage
#
#   calculation
# 0  PERCENTAGE
# 1  PERCENTAGE
# 2      MEDIAN
# 3  PERCENTAGE
# 4  PERCENTAGE

# %%
locations = pd.read_csv('locations-pa.csv')

# %%
locations.head()
# Out:
#       id    type          name
# 0     PA   state  Pennsylvania
# 1  PA001  county         Adams
# 2  PA003  county     Allegheny
# 3  PA005  county     Armstrong
# 4  PA007  county        Beaver

# %%
filters = pd.read_csv('filters.csv')

# %%
filters.head(10)
# Out:
#    id                             description
# 0   1                          all defendants
# 1  10                        white defendants
# 2  11             African American defendants
# 3  12            Hispanic / Latino defendants
# 4  13   Native American or Alaskan defendants
# 5  14    Asian or Pacific Islander defendants
# 6  15                     defendants of color
# 7  16  defendants of unknown race / ethnicity
# 8  20                         male defendants
# 9  21                       female defendants

# %%
data[(data['measure_id'] == 8) & (data['location_id'] == 'PA001') & (data['denominator'] > 4)].sort_values('denominator')
# Out:
#        measure_id  filter_id  start_year  end_year location_id  numerator  \
# 9521            8      81802        2009      2013       PA001        0.0
# 5645            8         22        2009      2013       PA001        0.0
# 9317            8         55        2009      2013       PA001        1.0
# 9453            8      81801        2009      2013       PA001        4.0
# 5441            8         32        2009      2013       PA001        2.0
# 9657            8      81804        2009      2013       PA001        1.0
# 6597            8      81201        2009      2013       PA001        5.0
# 6733            8      81203        2009      2013       PA001        5.0
# 8637            8       8103        2009      2013       PA001        4.0
# 4965            8         16        2009      2013       PA001        0.0
# 9589            8      81803        2009      2013       PA001        2.0
# 6937            8      81206        2009      2013       PA001        0.0
# ...

# %% [markdown]
# ### State data exploration

# %%
state = data[data.location_id == 'PA']

# %%
state.head()
# Out:
#      measure_id  filter_id  start_year  end_year location_id  numerator  \
# 0             7          1        2009      2013          PA    98382.0
# 68            7         10        2009      2013          PA    74518.0
# 136           7         15        2009      2013          PA    17089.0
# 204           7         16        2009      2013          PA     6728.0
# 272           7         11        2009      2013          PA    16183.0
#
#      denominator    value  missing  missing_percentage               status  \
# 0       134310.0  73.2499   8035.0              5.6447  HIGH_MISSING_UNFILT
# 68      100312.0  74.2862   5799.0              5.4650  HIGH_MISSING_PARENT
# 136      25061.0  68.1896   1683.0              6.2930  HIGH_MISSING_PARENT
# 204       8876.0  75.7999    552.0              5.8549  HIGH_MISSING_PARENT
# 272      23772.0  68.0759   1635.0              6.4352  HIGH_MISSING_PARENT
#
#      count  sum  sum_squares  minimum  maximum  standard_deviation  average
# ...

# %%
state.shape
# Out:
# (2952, 18)

# %% [markdown]
# white vs color filters

# %%
race = state[(state.filter_id == 10) | (state.filter_id == 15)]

# %%
race.shape
# Out:
# (62, 18)

# %%
race.plot(x='measure_id', y='value', kind='bar', figsize=(15,15))

# %%
race[race.measure_id == 7].plot(x='filter_id', y='value', kind='bar', figsize=(5,5))

# %%
race[race.measure_id == 8].plot(x='filter_id', y='value', kind='bar', figsize=(5,5))

# %%
race[race.measure_id == 10].plot(x='filter_id', y='value', kind='bar', figsize=(5,5))

# %%
values = race.pivot(index='measure_id', columns='filter_id', values='value')

# %%
values.plot(kind='bar',figsize=(15,10))

# %% [markdown]
# to do: keep only the percentage ones
